# %% [markdown]
# ## Time-Series Visualization using plotly
#
# ### Jing Song
#
# **This notebook is implementing the time-series visualization techniques with interaction using plotly.**

# %%
import plotly.plotly as py
import plotly.graph_objs as go

from datetime import datetime
import pandas as pd
import numpy as np

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from IPython.display import display, HTML

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import plotly
plotly.__version__
# Out:
# '2.5.1'

# %%
crime_data = pd.read_csv('Monthly_Property_Crime_2005_to_2015.csv')

# %%
crime_data.head()
# Out:
#                      Date       Category  IncidntNum
# 0  02/01/2014 12:00:00 AM       BURGLARY         506
# 1  02/01/2007 12:00:00 AM      VANDALISM         531
# 2  07/01/2012 12:00:00 AM       BURGLARY         522
# 3  07/01/2013 12:00:00 AM  LARCENY/THEFT        3318
# 4  08/01/2010 12:00:00 AM      VANDALISM         694

# %% [markdown]
# ### 1) Line charts

# %%
crime_data['Category'].value_counts()
# Out:
# STOLEN PROPERTY    132
# VEHICLE THEFT      132
# VANDALISM          132
# LARCENY/THEFT      132
# ARSON              132
# BURGLARY           132
# Name: Category, dtype: int64

# %%
date = pd.to_datetime(crime_data['Date']).sort_values()

# %%
crime_data['Date'] = pd.to_datetime(crime_data['Date'])

# %%
STOLEN_PROPERTY = crime_data.loc[crime_data['Category']=='STOLEN PROPERTY', ].sort_values('Date')

# %%
trace = go.Scatter(
    x = STOLEN_PROPERTY['Date'],
    y = STOLEN_PROPERTY['IncidntNum'],
    name = 'STOLEN PROPERTY',
)

data = [trace]

layout = go.Layout(title = 'Monthly Property Crime in San Francisco from 2005 to 2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Number of Incidents'),
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='basic-line')
# Out:
# <div id="57aa114b-764e-452f-8926-e0217b00df5a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("57aa114b-764e-452f-8926-e0217b00df5a", [{"y": [56, 40, 46, 41, 56, 40, 50, 43, 36, 49, 32, 51, 55, 46, 64, 67, 53, 49, 37, 47, 44, 48, 33, 32, 46, 33, 46, 48, 44, 54, 37, 32, 54, 54, 41, 38, 32, 35, 38, 31, 41, 39, 40, 52, 58, 63, 46, 43, 46, 50, 63, 53, 48, 52, 56, 55, 61, 59, 57, 60, 64, 51, 56, 58, 59, 56, 50, 66, 49, 59, 57, 55, 77, 62, 58, 55, 66, 69, 47, 81, 67, 64, 76, 63, 75, 71, 69, 62, 94, 61, 73, 83, 88, 82, 93, 81, 103, 79, 88, 102, 100, 89, 104, 129, 118, 120, 89, 103, 86, 99, 98, 92, 89, 77, 91, 92, 84, 106, 80, 90, 82, 84, 92, 77, 68, 75, 87, 84, 90, 84, 65, 71], "x": ["2005-01-01", "2005-02-01", "2005-03-01", "2005-04-01", "2005-05-01", "2005-06-01", "2005-07-01", "2005-08-01", "2005-09-01", "2005-10-01", "2005-11-01", "2005-12-01", "2006-01-01", "2006-02-01", "2006-03-01", "2006-04-01", "2006-05-01", "2006-06-01", "2006-07-01", "2006-08-01", "2006-09-01", "2006-10-01", "2006-11-01", "2006-12-01", "2007-01-01", "2007-02-01", "2007-03-01", "2007-04-01", "2007-05-01", "2007-06-01", "2007-07-01", "2007-08-01", "2007-09-01", "2007-10-01", "2007-11-01", "2007-12-01", "2008-01-01", "2008-02-01", "2008-03-01", "2008-04-01", "2008-05-01", "2008-06-01", "2008-07-01", "2008-08-01", "2008-09-01", "2008-10-01", "2008-11-01", "2008-12-01", "2009-01-01", "2009-02-01", "2009-03-01", "2009-04-01", "2009-05-01", "2009-06-01", "2009-07-01", "2009-08-01", "2009-09-01", "2009-10-01", "2009-11-01", "2009-12-01", "2010-01-01", "2010-02-01", "2010-03-01", "2010-04-01", "2010-05-01", "2010-06-01", "2010-07-01", "2010-08-01", "2010-09-01", "2010-10-01", "2010-11-01", "2010-12-01", "2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-06-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01"], "type": "scatter", "name": "STOLEN PROPERTY"}], {"showlegend": true, "title": "Monthly Property Crime in San Francisco from 2005 to 2015", "xaxis": {"title": "Year"}, "yaxis": {"title": "Number of Incidents"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# **Above is the line chart showing the monthly number of stolen property in San Francisco from 2005 to 2015.**

# %% [markdown]
# ### 2) Multi line charts

# %%
data = []
for crime in crime_data['Category'].unique():
    df = crime_data.loc[crime_data['Category']==crime, ].sort_values('Date')
    
    trace = go.Scatter(
    x = df['Date'],
    y = df['IncidntNum'],
    name = crime,
    )
    
    data.append(trace)

layout = go.Layout(title = 'Monthly Property Crime in San Francisco from 2005 to 2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Number of Incidents'),
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='multi-line')
# Out:
# <div id="a463de0c-ff7f-4484-a66b-ee2d54a5cf03" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a463de0c-ff7f-4484-a66b-ee2d54a5cf03", [{"y": [698, 547, 654, 551, 622, 586, 691, 595, 531, 526, 511, 559, 527, 515, 576, 616, 621, 600, 656, 658, 562, 508, 585, 580, 501, 382, 426, 476, 426, 448, 509, 474, 385, 456, 482, 489, 434, 382, 470, 440, 458, 438, 500, 473, 542, 494, 523, 525, 441, 389, 499, 491, 441, 432, 475, 453, 415, 430, 437, 476, 421, 374, 404, 436, 492, 457, 432, 403, 385, 393, 382, 387, 442, 315, 374, 377, 406, 390, 378, 466, 467, 421, 475, 476, 471, 464, 475, 536, 523, 495, 522, 547, 482, 594, 584, 550, 507, 440, 519, 540, 508, 484, 534, 534, 568, 525, 517, 519, 618, 506, 563, 485, 485, 442, 499, 479, 457, 553, 462, 517, 495, 481, 513, 490, 568, 498, 490, 490, 467, 458, 457, 524], "x": ["2005-01-01", "2005-02-01", "2005-03-01", "2005-04-01", "2005-05-01", "2005-06-01", "2005-07-01", "2005-08-01", "2005-09-01", "2005-10-01", "2005-11-01", "2005-12-01", "2006-01-01", "2006-02-01", "2006-03-01", "2006-04-01", "2006-05-01", "2006-06-01", "2006-07-01", "2006-08-01", "2006-09-01", "2006-10-01", "2006-11-01", "2006-12-01", "2007-01-01", "2007-02-01", "2007-03-01", "2007-04-01", "2007-05-01", "2007-06-01", "2007-07-01", "2007-08-01", "2007-09-01", "2007-10-01", "2007-11-01", "2007-12-01", "2008-01-01", "2008-02-01", "2008-03-01", "2008-04-01", "2008-05-01", "2008-06-01", "2008-07-01", "2008-08-01", "2008-09-01", "2008-10-01", "2008-11-01", "2008-12-01", "2009-01-01", "2009-02-01", "2009-03-01", "2009-04-01", "2009-05-01", "2009-06-01", "2009-07-01", "2009-08-01", "2009-09-01", "2009-10-01", "2009-11-01", "2009-12-01", "2010-01-01", "2010-02-01", "2010-03-01", "2010-04-01", "2010-05-01", "2010-06-01", "2010-07-01", "2010-08-01", "2010-09-01", "2010-10-01", "2010-11-01", "2010-12-01", "2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-06-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01"], "type": "scatter", "name": "BURGLARY"}, {"y": [493, 462, 585, 581, 658, 622, 643, 616, 559, 655, 581, 558, 601, 602, 621, 741, 678, 602, 660, 687, 672, 664, 560, 600, 648, 531, 682, 612, 643, 644, 738, 604, 639, 690, 596, 539, 642, 546, 653, 664, 635, 567, 601, 582, 579, 711, 602, 560, 556, 481, 623, 660, 554, 537, 675, 714, 688, 750, 684, 682, 702, 588, 609, 687, 719, 715, 650, 694, 685, 680, 635, 570, 663, 590, 684, 683, 601, 571, 598, 562, 525, 595, 541, 630, 605, 604, 642, 659, 606, 614, 675, 663, 687, 807, 648, 598, 566, 526, 657, 610, 515, 561, 598, 558, 630, 587, 516, 597, 577, 546, 603, 619, 592, 508, 616, 632, 604, 635, 611, 622, 616, 513, 678, 587, 672, 662, 773, 729, 663, 674, 561, 547], "x": ["2005-01-01", "2005-02-01", "2005-03-01", "2005-04-01", "2005-05-01", "2005-06-01", "2005-07-01", "2005-08-01", "2005-09-01", "2005-10-01", "2005-11-01", "2005-12-01", "2006-01-01", "2006-02-01", "2006-03-01", "2006-04-01", "2006-05-01", "2006-06-01", "2006-07-01", "2006-08-01", "2006-09-01", "2006-10-01", "2006-11-01", "2006-12-01", "2007-01-01", "2007-02-01", "2007-03-01", "2007-04-01", "2007-05-01", "2007-06-01", "2007-07-01", "2007 ...

# %% [markdown]
# **Above is the multi-line charts showing the monthly number of property crime in San Francisco from 2005 to 2015. The different categories of crimes are shown in different colors.**

# %% [markdown]
# ### 3) Bar charts

# %%
data = []
for crime in ['STOLEN PROPERTY']:
    df = crime_data.loc[crime_data['Category']==crime, ].sort_values('Date')
    
    trace = go.Bar(
    x = df['Date'],
    y = df['IncidntNum'],
    name = crime,
    )
    
    data.append(trace)

layout = go.Layout(title = 'Monthly Property Crime in San Francisco from 2005 to 2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Number of Incidents'),
              barmode='bar',
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='bar')
# Out:
# <div id="d3c64060-41d6-4594-8ac5-5b32c976c6a2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d3c64060-41d6-4594-8ac5-5b32c976c6a2", [{"y": [56, 40, 46, 41, 56, 40, 50, 43, 36, 49, 32, 51, 55, 46, 64, 67, 53, 49, 37, 47, 44, 48, 33, 32, 46, 33, 46, 48, 44, 54, 37, 32, 54, 54, 41, 38, 32, 35, 38, 31, 41, 39, 40, 52, 58, 63, 46, 43, 46, 50, 63, 53, 48, 52, 56, 55, 61, 59, 57, 60, 64, 51, 56, 58, 59, 56, 50, 66, 49, 59, 57, 55, 77, 62, 58, 55, 66, 69, 47, 81, 67, 64, 76, 63, 75, 71, 69, 62, 94, 61, 73, 83, 88, 82, 93, 81, 103, 79, 88, 102, 100, 89, 104, 129, 118, 120, 89, 103, 86, 99, 98, 92, 89, 77, 91, 92, 84, 106, 80, 90, 82, 84, 92, 77, 68, 75, 87, 84, 90, 84, 65, 71], "x": ["2005-01-01", "2005-02-01", "2005-03-01", "2005-04-01", "2005-05-01", "2005-06-01", "2005-07-01", "2005-08-01", "2005-09-01", "2005-10-01", "2005-11-01", "2005-12-01", "2006-01-01", "2006-02-01", "2006-03-01", "2006-04-01", "2006-05-01", "2006-06-01", "2006-07-01", "2006-08-01", "2006-09-01", "2006-10-01", "2006-11-01", "2006-12-01", "2007-01-01", "2007-02-01", "2007-03-01", "2007-04-01", "2007-05-01", "2007-06-01", "2007-07-01", "2007-08-01", "2007-09-01", "2007-10-01", "2007-11-01", "2007-12-01", "2008-01-01", "2008-02-01", "2008-03-01", "2008-04-01", "2008-05-01", "2008-06-01", "2008-07-01", "2008-08-01", "2008-09-01", "2008-10-01", "2008-11-01", "2008-12-01", "2009-01-01", "2009-02-01", "2009-03-01", "2009-04-01", "2009-05-01", "2009-06-01", "2009-07-01", "2009-08-01", "2009-09-01", "2009-10-01", "2009-11-01", "2009-12-01", "2010-01-01", "2010-02-01", "2010-03-01", "2010-04-01", "2010-05-01", "2010-06-01", "2010-07-01", "2010-08-01", "2010-09-01", "2010-10-01", "2010-11-01", "2010-12-01", "2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-06-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01"], "type": "bar", "name": "STOLEN PROPERTY"}], {"barmode": "bar", "showlegend": true, "title": "Monthly Property Crime in San Francisco from 2005 to 2015", "xaxis": {"title": "Year"}, "yaxis": {"title": "Number of Incidents"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# **Above is the bar chart showing the monthly number of stolen property in San Francisco from 2005 to 2015.**

# %% [markdown]
# ### 4) Stacked area charts

# %%
crime_data_sum = crime_data.groupby('Date').sum().reset_index()
crime_data_agg = pd.merge(crime_data, crime_data_sum, how='left', on=['Date'])
crime_data_agg['IncidntPct'] = crime_data_agg['IncidntNum_x']/ crime_data_agg['IncidntNum_y']
crime_data_agg.head()
# Out:
#         Date       Category  IncidntNum_x  IncidntNum_y  IncidntPct
# 0 2014-02-01       BURGLARY           506          4164    0.121518
# 1 2007-02-01      VANDALISM           531          3067    0.173133
# 2 2012-07-01       BURGLARY           522          4459    0.117067
# 3 2013-07-01  LARCENY/THEFT          3318          5074    0.653922
# 4 2010-08-01      VANDALISM           694          3855    0.180026

# %%
data = []
y_stack = []
for crime in crime_data['Category'].unique():
    df = crime_data_agg.loc[crime_data_agg['Category']==crime, ].sort_values('Date')
    y_original = np.around(df['IncidntPct'].reset_index(drop=True)*100, decimals=2)
    
    if len(y_stack) == 0:
        y_stack = y_original
    else:
        y_stack = [y0+y1 for y0, y1 in zip(y_original, y_stack)]
        
    y_text = [str(y0)+'%' for y0 in y_original]
    
    
    trace = go.Scatter(
    x = df['Date'],
    y = y_stack,
    text=y_text,
    name = crime,
    hoverinfo='x+name+text',
    mode='lines',
    fill='tonexty'
    )
    
    data.append(trace)

layout = go.Layout(title = 'Composition of Monthly Property Crime in San Francisco from 2005 to 2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Percentage of Total Incidents'),
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='stacked-area-plot')
# Out:
# <div id="aed0912d-8599-44a9-8eb5-89154b35eb3f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aed0912d-8599-44a9-8eb5-89154b35eb3f", [{"name": "BURGLARY", "text": ["13.99%", "13.13%", "13.58%", "11.7%", "12.15%", "11.92%", "13.44%", "11.68%", "11.13%", "10.13%", "10.51%", "12.18%", "12.65%", "13.46%", "13.79%", "13.96%", "14.54%", "14.33%", "15.4%", "14.59%", "13.47%", "11.92%", "14.99%", "14.48%", "13.47%", "12.46%", "11.37%", "13.29%", "11.69%", "11.63%", "11.36%", "11.03%", "9.19%", "11.04%", "12.97%", "13.57%", "11.41%", "11.44%", "11.92%", "10.93%", "11.96%", "12.63%", "13.1%", "12.39%", "13.52%", "11.54%", "14.09%", "14.61%", "12.46%", "12.21%", "12.93%", "13.39%", "12.78%", "13.13%", "11.87%", "10.69%", "10.57%", "10.98%", "11.53%", "12.62%", "11.42%", "12.15%", "12.04%", "13.17%", "14.08%", "12.78%", "11.81%", "10.45%", "10.35%", "10.76%", "10.41%", "10.99%", "12.09%", "9.78%", "9.7%", "10.67%", "11.04%", "11.36%", "11.07%", "12.79%", "12.94%", "10.7%", "12.51%", "11.58%", "12.37%", "12.4%", "12.61%", "13.16%", "12.29%", "11.79%", "11.71%", "11.56%", "10.02%", "11.42%", "12.19%", "12.1%", "10.86%", "10.44%", "11.25%", "11.72%", "11.66%", "11.05%", "10.52%", "10.08%", "10.07%", "10.12%", "11.17%", "11.35%", "12.95%", "12.15%", "11.67%", "9.93%", "10.43%", "9.87%", "9.85%", "8.68%", "9.29%", "9.78%", "8.81%", "9.39%", "8.91%", "9.73%", "8.92%", "9.08%", "9.45%", "8.67%", "8.33%", "8.67%", "8.82%", "8.77%", "9.74%", "11.03%"], "mode": "lines", "hoverinfo": "x+name+text", "y": [13.99, 13.13, 13.58, 11.7, 12.15, 11.92, 13.44, 11.68, 11.13, 10.13, 10.51, 12.18, 12.65, 13.46, 13.79, 13.96, 14.54, 14.33, 15.4, 14.59, 13.47, 11.92, 14.99, 14.48, 13.47, 12.46, 11.37, 13.29, 11.69, 11.63, 11.36, 11.03, 9.19, 11.04, 12.97, 13.57, 11.41, 11.44, 11.92, 10.93, 11.96, 12.63, 13.1, 12.39, 13.52, 11.54, 14.09, 14.61, 12.46, 12.21, 12.93, 13.39, 12.78, 13.13, 11.87, 10.69, 10.57, 10.98, 11.53, 12.62, 11.42, 12.15, 12.04, 13.17, 14.08, 12.78, 11.81, 10.45, 10.35, 10.76, 10.41, 10.99, 12.09, 9.78, 9.7, 10.67, 11.04, 11.36, 11.07, 12.79, 12.94, 10.7, 12.51, 11.58, 12.37, 12.4, 12.61, 13.16, 12.29, 11.79, 11.71, 11.56, 10.02, 11.42, 12.19, 12.1, 10.86, 10.44, 11.25, 11.72, 11.66, 11.05, 10.52, 10.08, 10.07, 10.12, 11.17, 11.35, 12.95, 12.15, 11.67, 9.93, 10.43, 9.87, 9.85, 8.68, 9.29, 9.78, 8.81, 9.39, 8.91, 9.73, 8.92, 9.08, 9.45, 8.67, 8.33, 8.67, 8.82, 8.77, 9.74, 11.03], "x": ["2005-01-01", "2005-02-01", "2005-03-01", "2005-04-01", "2005-05-01", "2005-06-01", "2005-07-01", "2005-08-01", "2005-09-01", "2005-10-01", "2005-11-01", "2005-12-01", "2006-01-01", "2006-02-01", "2006-03-01", "2006-04-01", "2006-05-01", "2006-06-01", "2006-07-01", "2006-08-01", "2006-09-01", "2006-10-01", "2006-11-01", "2006-12-01", "2007-01-01", "2007-02-01", "2007-03-01", "2007-04-01", "2007-05-01", "2007-06-01", "2007-07-01", "2007-08-01", "2007-09-01", "2007-10-01", "2007-11-01", "2007-12-01", "2008-01-01", "2008-02-01", "2008-03-01", "2008-04-01", "2008-05-01", "2008-06-01", "2008-07-01", "2008-08-01", "2008-09-01", "2008-10-01", "2008-11-01", "2008-12-01", "2009-01-01", "2009-02-01", "2009-03-01", "2009-04-01", "2009-05-01", "2009-06-01", "2009-07-01", "2009-08-01", "2009-09-01", "2009-10-01", "2009-11-01", "2009-12-01", "2010-01-01", "2010-02-01", "2010-03-01", "2010-04-01", "2010-05-01", "2010-06-01", "2010-07-01", "2010-08-01", "2010-09-01", "2010-10-01", "2010-11-01", "2010-12-01", "2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", " ...

# %% [markdown]
# **Above is the stacked area charts showing the monthly composition of property crime in San Francisco from 2005 to 2015. The different categories of crimes are shown in different colors.**

# %% [markdown]
# ### 5) Stacked bar charts

# %%
data = []
for crime in ['STOLEN PROPERTY', 'ARSON']:
    df = crime_data.loc[crime_data['Category']==crime, ].sort_values('Date')
    
    trace = go.Bar(
    x = df['Date'],
    y = df['IncidntNum'],
    name = crime,
    )
    
    data.append(trace)

layout = go.Layout(title = 'Monthly Property Crime in San Francisco from 2005 to 2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title = 'Number of Incidents'),
              barmode='stack',
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar-stacked')
# Out:
# <div id="f0784fc2-0f97-468a-a4c5-a0c905563ea9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f0784fc2-0f97-468a-a4c5-a0c905563ea9", [{"y": [56, 40, 46, 41, 56, 40, 50, 43, 36, 49, 32, 51, 55, 46, 64, 67, 53, 49, 37, 47, 44, 48, 33, 32, 46, 33, 46, 48, 44, 54, 37, 32, 54, 54, 41, 38, 32, 35, 38, 31, 41, 39, 40, 52, 58, 63, 46, 43, 46, 50, 63, 53, 48, 52, 56, 55, 61, 59, 57, 60, 64, 51, 56, 58, 59, 56, 50, 66, 49, 59, 57, 55, 77, 62, 58, 55, 66, 69, 47, 81, 67, 64, 76, 63, 75, 71, 69, 62, 94, 61, 73, 83, 88, 82, 93, 81, 103, 79, 88, 102, 100, 89, 104, 129, 118, 120, 89, 103, 86, 99, 98, 92, 89, 77, 91, 92, 84, 106, 80, 90, 82, 84, 92, 77, 68, 75, 87, 84, 90, 84, 65, 71], "x": ["2005-01-01", "2005-02-01", "2005-03-01", "2005-04-01", "2005-05-01", "2005-06-01", "2005-07-01", "2005-08-01", "2005-09-01", "2005-10-01", "2005-11-01", "2005-12-01", "2006-01-01", "2006-02-01", "2006-03-01", "2006-04-01", "2006-05-01", "2006-06-01", "2006-07-01", "2006-08-01", "2006-09-01", "2006-10-01", "2006-11-01", "2006-12-01", "2007-01-01", "2007-02-01", "2007-03-01", "2007-04-01", "2007-05-01", "2007-06-01", "2007-07-01", "2007-08-01", "2007-09-01", "2007-10-01", "2007-11-01", "2007-12-01", "2008-01-01", "2008-02-01", "2008-03-01", "2008-04-01", "2008-05-01", "2008-06-01", "2008-07-01", "2008-08-01", "2008-09-01", "2008-10-01", "2008-11-01", "2008-12-01", "2009-01-01", "2009-02-01", "2009-03-01", "2009-04-01", "2009-05-01", "2009-06-01", "2009-07-01", "2009-08-01", "2009-09-01", "2009-10-01", "2009-11-01", "2009-12-01", "2010-01-01", "2010-02-01", "2010-03-01", "2010-04-01", "2010-05-01", "2010-06-01", "2010-07-01", "2010-08-01", "2010-09-01", "2010-10-01", "2010-11-01", "2010-12-01", "2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-06-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01"], "type": "bar", "name": "STOLEN PROPERTY"}, {"y": [21, 17, 19, 24, 13, 23, 23, 20, 17, 18, 19, 17, 24, 13, 16, 19, 27, 14, 24, 24, 27, 27, 11, 14, 23, 12, 17, 20, 29, 21, 29, 16, 27, 18, 23, 11, 16, 12, 34, 20, 18, 20, 21, 24, 28, 18, 20, 17, 20, 17, 16, 18, 17, 15, 30, 19, 18, 14, 25, 13, 19, 9, 19, 16, 21, 22, 18, 22, 19, 21, 17, 6, 25, 19, 11, 23, 14, 13, 20, 17, 18, 14, 17, 12, 29, 16, 12, 18, 17, 21, 25, 17, 25, 18, 18, 21, 37, 23, 22, 11, 19, 20, 25, 17, 19, 21, 24, 10, 32, 22, 13, 18, 15, 25, 20, 20, 14, 24, 28, 22, 41, 31, 21, 30, 30, 31, 23, 16, 16, 28, 25, 19], "x": ["2005-01-01", "2005-02-01", "2005-03-01", "2005-04-01", "2005-05-01", "2005-06-01", "2005-07-01", "2005-08-01", "2005-09-01", "2005-10-01", "2005-11-01", "2005-12-01", "2006-01-01", "2006-02-01", "2006-03-01", "2006-04-01", "2006-05-01", "2006-06-01", "2006-07-01", "2006-08-01", "2006-09-01", "2006-10-01", "2006-11-01", "2006-12-01", "2007-01-01", "2007-02-01", "2007-03-01", "2007-04-01", "2007-05-01", "2007-06-01", "2007-07-01", "2007-08-01", "2007-09-01", "2007-10-01", "2007-11-01", "2007-12-01", "2008-01-01", "2008-02-01", "2008-03-01", "2008-04-01", "2008-05-01", "2008-06-01", "2008-07-01", "2008-08-01", "2008-09-01", "2008-10-01", "2008-11-01", "2008-12-01", "2009-01-01", "2009-0 ...

# %% [markdown]
# **Above is the stacked bar chart showing the monthly number of stolen property and arson in San Francisco from 2005 to 2015.**

# %% [markdown]
# ### 6) Heatmap

# %%
import datetime

# %%
data = []
z = []

for crime in crime_data['Category'].unique():
    df = crime_data.loc[crime_data['Category']==crime, ].sort_values('Date')
    z.append(list(df['IncidntNum']))
    
trace = go.Heatmap(
    z = z, 
    x = pd.to_datetime(crime_data['Date'].sort_values().unique()).to_pydatetime(),
    y = crime_data['Category'],
    name = crime,
    colorscale='Viridis',
)
    
data = [trace]

layout = go.Layout(title = 'Monthly Property Crime in San Francisco from 2005 to 2015',
              xaxis = dict(title = 'Year'),
              yaxis = dict(title='Incidents',
                            titlefont=dict(size=14),
                            showticklabels=True,
                            tickangle=45,
                            tickfont=dict(size=8)),
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='heatmap')
# Out:
# <div id="d9d5a5f2-94db-40e1-9570-191ed06f7f01" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d9d5a5f2-94db-40e1-9570-191ed06f7f01", [{"name": "ARSON", "colorscale": "Viridis", "y": ["BURGLARY", "VANDALISM", "BURGLARY", "LARCENY/THEFT", "VANDALISM", "BURGLARY", "VEHICLE THEFT", "LARCENY/THEFT", "STOLEN PROPERTY", "STOLEN PROPERTY", "ARSON", "ARSON", "ARSON", "STOLEN PROPERTY", "VEHICLE THEFT", "VANDALISM", "VEHICLE THEFT", "LARCENY/THEFT", "VEHICLE THEFT", "LARCENY/THEFT", "ARSON", "STOLEN PROPERTY", "VEHICLE THEFT", "STOLEN PROPERTY", "VANDALISM", "STOLEN PROPERTY", "VANDALISM", "STOLEN PROPERTY", "ARSON", "STOLEN PROPERTY", "STOLEN PROPERTY", "ARSON", "VEHICLE THEFT", "VEHICLE THEFT", "LARCENY/THEFT", "VANDALISM", "ARSON", "LARCENY/THEFT", "LARCENY/THEFT", "BURGLARY", "STOLEN PROPERTY", "LARCENY/THEFT", "VANDALISM", "BURGLARY", "VANDALISM", "BURGLARY", "STOLEN PROPERTY", "BURGLARY", "STOLEN PROPERTY", "VANDALISM", "STOLEN PROPERTY", "VANDALISM", "VANDALISM", "ARSON", "STOLEN PROPERTY", "ARSON", "LARCENY/THEFT", "ARSON", "ARSON", "LARCENY/THEFT", "VEHICLE THEFT", "ARSON", "VANDALISM", "BURGLARY", "VEHICLE THEFT", "VEHICLE THEFT", "BURGLARY", "VANDALISM", "STOLEN PROPERTY", "VANDALISM", "ARSON", "VANDALISM", "VANDALISM", "VEHICLE THEFT", "STOLEN PROPERTY", "LARCENY/THEFT", "STOLEN PROPERTY", "VEHICLE THEFT", "ARSON", "BURGLARY", "STOLEN PROPERTY", "VANDALISM", "ARSON", "VANDALISM", "ARSON", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "BURGLARY", "LARCENY/THEFT", "VEHICLE THEFT", "ARSON", "VANDALISM", "ARSON", "LARCENY/THEFT", "VEHICLE THEFT", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "BURGLARY", "BURGLARY", "LARCENY/THEFT", "VANDALISM", "BURGLARY", "VANDALISM", "LARCENY/THEFT", "VANDALISM", "BURGLARY", "STOLEN PROPERTY", "VANDALISM", "BURGLARY", "STOLEN PROPERTY", "ARSON", "STOLEN PROPERTY", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "ARSON", "VANDALISM", "BURGLARY", "STOLEN PROPERTY", "ARSON", "VEHICLE THEFT", "STOLEN PROPERTY", "VANDALISM", "ARSON", "BURGLARY", "VANDALISM", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "LARCENY/THEFT", "BURGLARY", "VEHICLE THEFT", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "BURGLARY", "LARCENY/THEFT", "ARSON", "STOLEN PROPERTY", "BURGLARY", "STOLEN PROPERTY", "BURGLARY", "LARCENY/THEFT", "BURGLARY", "VANDALISM", "STOLEN PROPERTY", "VANDALISM", "BURGLARY", "ARSON", "VEHICLE THEFT", "VEHICLE THEFT", "VANDALISM", "VANDALISM", "VEHICLE THEFT", "LARCENY/THEFT", "STOLEN PROPERTY", "STOLEN PROPERTY", "VEHICLE THEFT", "ARSON", "VANDALISM", "BURGLARY", "ARSON", "VANDALISM", "VEHICLE THEFT", "BURGLARY", "ARSON", "ARSON", "VEHICLE THEFT", "ARSON", "BURGLARY", "VEHICLE THEFT", "BURGLARY", "ARSON", "VEHICLE THEFT", "VEHICLE THEFT", "VANDALISM", "ARSON", "BURGLARY", "VANDALISM", "BURGLARY", "STOLEN PROPERTY", "ARSON", "ARSON", "VEHICLE THEFT", "ARSON", "BURGLARY", "ARSON", "BURGLARY", "ARSON", "BURGLARY", "LARCENY/THEFT", "BURGLARY", "BURGLARY", "LARCENY/THEFT", "LARCENY/THEFT", "VEHICLE THEFT", "ARSON", "STOLEN PROPERTY", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "STOLEN PROPERTY", "LARCENY/THEFT", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "STOLEN PROPERTY", "STOLEN PROPERTY", "VANDALISM", "ARSON", "LARCENY/THEFT", "BURGLARY", "ARSON", "STOLEN PROPERTY", "ARSON", "BURGLARY", "LARCENY/THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "VANDALISM", "ARSON", "STOLEN PROPERTY", "VEHICLE THEFT", "VANDALISM", "VEHICLE THEFT", "VEHICLE THEFT", "ARSON", "BURGLARY", "STOLEN PROPERTY", "VANDALISM", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "VANDALISM", "VANDALISM", "VEHICLE THEFT", "BURGLARY", "VANDALISM", "BURGLARY", "VEHICLE THEFT", "STOLEN PROPERTY", "LARCENY/THEFT", "VANDALISM", "LARCENY/THEFT", "VANDALISM", "BURGLARY", "VEHICLE THEFT", "VA ...

# %% [markdown]
# **Above is the heat map showing the monthly number of property crime in San Francisco from 2005 to 2015. The different categories of crimes are shown in different rows.
# **
